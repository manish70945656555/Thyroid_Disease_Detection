# %%
from pymongo.mongo_client import MongoClient
import pandas as pd
import json

# %%
# uniform resource indentifier
uri = "mongodb+srv://manishkumawat0803:sansad70@cluster0.necirxl.mongodb.net/?retryWrites=true&w=majority"



# Create a new client and connect to the server
client = MongoClient(uri)

# %%
# create database name and collection name
DATABASE_NAME="ThyroidProject"
COLLECTION_NAME="ThyroidDetection"

# %%
# read the data as a dataframe
df=pd.read_csv(r"D:\ThyroidDiseaseDetection\notebooks\data\thyroid.csv")

# Convert the data into json
json_record=list(json.loads(df.T.to_json()).values())

# %%
df.head()
# Out:
#   age sex on_thyroxine query_on_thyroxine on_antithyroid_medication  \
# 0  15   F            t                  f                         f
# 1  24   M            f                  f                         f
# 2  24   F            f                  f                         f
# 3  77   M            f                  f                         f
# 4  85   F            f                  f                         f
#
#   thyroid_surgery query_hypothyroid query_hyperthyroid pregnant sick  ...  \
# 0               f                 f                  f        f    f  ...
# 1               f                 f                  f        f    f  ...
# 2               f                 f                  f        f    f  ...
# 3               f                 f                  f        f    f  ...
# 4               f                 t                  f        f    f  ...
#
#      T3 TT4_measured TT4 T4U_measured   T4U FTI_measured FTI TBG_measured TBG  \
# 0  1.70            y  19            y  1.13            y  17            n   ?
# 1  0.20            y   4            y     1            y   0            n   ?
# 2  0.40            y   6            y  1.04            y   6            n   ?
# 3  1.20            y  57            y  1.28            y  44            n   ?
# 4  1.10            y  27            y  1.19            y  23            n   ?
#
#         Target
# 0  hypothyroid
# 1  hypothyroid
# 2  hypothyroid
# 3  hypothyroid
# 4  hypothyroid
#
# [5 rows x 26 columns]

# %%
# Convert the data into json
json_record=list(json.loads(df.T.to_json()).values())

# %%
#now dump the data into the database
client[DATABASE_NAME][COLLECTION_NAME].insert_many(json_record)
